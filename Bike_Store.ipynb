# %% [markdown]
# # SQL Queries & Data Visualization in Bike Store DB

# %% [markdown]
# Bike Store Relational Database is the sample database from sqlservertutorial.net.

# %% [markdown]
# ## Customer Segmentation

# %%
##!pip install pyodbc pandas matplotlib seaborn

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Load the result into a DataFrame
df = pd.read_excel(r'C:\Users\abudh\Desktop\Bike_Store_Relation\Customer_Segmentation.xlsx')
df
# Out:
#       customer_id purchase_frequency  purchase_recency     buying_power
# 0               1       repeat buyer      recent buyer      big spender
# 1               2       repeat buyer  not recent buyer  average spender
# 2               3       repeat buyer      recent buyer      big spender
# 3               4       repeat buyer  not recent buyer  average spender
# 4               5       repeat buyer  not recent buyer  average spender
# ...           ...                ...               ...              ...
# 1440         1441     one-time buyer  not recent buyer      low spender
# 1441         1442     one-time buyer  not recent buyer      low spender
# 1442         1443     one-time buyer  not recent buyer      low spender
# 1443         1444     one-time buyer  not recent buyer      low spender
# 1444         1445     one-time buyer  not recent buyer      low spender
#
# [1445 rows x 4 columns]

# %%
fig, ax = plt.subplots(ncols=3, figsize=(16, 4), sharey=True)
sns.countplot(data=df, x='purchase_frequency', ax=ax[0])
sns.countplot(data=df, x='purchase_recency', ax=ax[1])
sns.countplot(data=df, x='buying_power', ax=ax[2])
ax[0].set_title('Purchase Frequency')
ax[1].set_title('Purchase Recency')
ax[2].set_title('Buying Power')
for axis in ax:
    axis.set_ylabel('')
    axis.set_xlabel('')
plt.show()

# %% [markdown]
# ## Purchase Recency

# %%
df = pd.read_excel(r'C:\Users\abudh\Desktop\Bike_Store_Relation\purchase_recency.xlsx')
df
# Out:
#    purchase_recency  Total
# 0  not recent buyer   1441
# 1      recent buyer      4

# %%
df = pd.read_excel(r'C:\Users\abudh\Desktop\Bike_Store_Relation\Buying_Power.xlsx')
df
# Out:
#       buying_power  Total
# 0      big spender     17
# 1  average spender    175
# 2      low spender   1253

# %% [markdown]
# ## Seasonality Analysis

# %%
df = pd.read_excel(r'C:\Users\abudh\Desktop\Bike_Store_Relation\monthly_sales_by_category.xlsx')
df
# Out:
#     month        category_name  avg_units_sold
# 0       7           Road Bikes               2
# 1       3    Cruisers Bicycles               3
# 2       7       Electric Bikes               5
# 3       2  Cyclocross Bicycles               4
# 4       8       Mountain Bikes               4
# ..    ...                  ...             ...
# 79      8     Comfort Bicycles               3
# 80      2       Electric Bikes               2
# 81      5       Mountain Bikes               4
# 82      6           Road Bikes               3
# 83     12    Cruisers Bicycles               4
#
# [84 rows x 3 columns]

# %%
fig, ax = plt.subplots(figsize=(9,5))
sns.barplot(data=df, x='month', y='avg_units_sold', hue='category_name', errorbar=None, ax=ax)
ax.set_yticks([])
ax.set_ylabel('')
ax.set_xlabel('Month')
ax.set_title('Average Units Sold by Month of Year')
plt.show()

# %% [markdown]
# ## Ranking and Ordering Analysis
#
# Query to get the top 10 customers based on total purchase amount:

# %%
df = pd.read_excel(r'C:\Users\abudh\Desktop\Bike_Store_Relation\customer_transaction_ranking.xlsx')
df
# Out:
#          customer_name  total_transactions  rank
# 0      Elinore Aguilar                   3     1
# 1        Jamaal Albert                   3     1
# 2     Genoveva Baldwin                   3     1
# 3         Lyndsey Bean                   3     1
# 4        Lorrie Becker                   3     1
# ...                ...                 ...   ...
# 1439       Glady Wells                   1   133
# 1440      Vanessa West                   1   133
# 1441  Brenton Whitaker                   1   133
# 1442   Sharie Whitaker                   1   133
# 1443       Shila White                   1   133
#
# [1444 rows x 3 columns]

# %% [markdown]
# ## Market Basket Analysis
#
# Query to find frequently co-purchased products with a specific product:

# %%
df = pd.read_excel(r'C:\Users\abudh\Desktop\Bike_Store_Relation\co_purchased_products.xlsx')
df
# Out:
#                                           product_a  \
# 0     Electra Girl's Hawaii 1 (16-inch) - 2015/2016
# 1                Electra Cruiser 1 (24-Inch) - 2016
# 2                Electra Townie Original 21D - 2016
# 3                Electra Cruiser 1 (24-Inch) - 2016
# 4                Electra Cruiser 1 (24-Inch) - 2016
# ...                                             ...
# 6471                Trek Domane AL 3 Women's - 2018
# 6472          Trek Domane ALR 4 Disc Women's - 2018
# 6473                    Trek Domane S 5 Disc - 2017
# 6474                         Trek Domane S 6 - 2017
# 6475                         Trek Emonda S 5 - 2017
#
#                                           product_b  co_purchase_count
# 0                Electra Cruiser 1 (24-Inch) - 2016                 35
# 1     Electra Girl's Hawaii 1 (16-inch) - 2015/2016                 35
# 2                Electra Cruiser 1 (24-Inch) - 2016                 34
# ...

# %% [markdown]
# ## Time Intervals between Engagements
#
# Query to calculate average time between consecutive purchases for customers:

# %%
df = pd.read_excel(r'C:\Users\abudh\Desktop\Bike_Store_Relation\avg_purchase_interval.xlsx')
df
# Out:
#      customer_id  avg_days_between_purchases
# 0              1                         354
# 1              2                         214
# 2              3                         104
# 3              4                         217
# 4              5                         338
# ..           ...                         ...
# 126          231                         133
# 127          233                         314
# 128          237                         727
# 129          239                         263
# 130          240                         597
#
# [131 rows x 2 columns]
